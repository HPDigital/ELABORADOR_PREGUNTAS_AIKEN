# %% [markdown]
# ### Step 1: Create a new Assistant with File Search Enabled

# %%
from openai import OpenAI
 
client = OpenAI(api_key="YOUR_API_KEY_HERE")
 
assistant = client.beta.assistants.create(
  name="Elaborador",
  instructions="""Eres un experto en elaboracion de preguntas didacticas para evaluaciones, 
  NUNCA proporcionas las fuentes ni haces citacines
  NUNCA das un texto de introduccion , ni de despedida 
  UNICAMENTE respondes con las preguntas solictadas haciendo como en el ejemplo, no mas y no menos""",
  model="gpt-4o",
  tools=[{"type": "file_search"}],
)

# %%
# Create a vector store caled "Financial Statements"
vector_store = client.beta.vector_stores.create(name="Texto_adjunto")
 
# Ready the files for upload to OpenAI
file_paths = ["C:\\Users\\HP\\Desktop\\CATO CURSOS-1-2024\\GER-TI CATO1-2024\\Cursos\\SEMANA 17\\PREGUNTAS  AIKEN\\Charla virtual 10 estartegias de marketing.txt"]
file_streams = [open(path, "rb") for path in file_paths]
 
# Use the upload and poll SDK helper to upload the files, add them to the vector store,
# and poll the status of the file batch for completion.
file_batch = client.beta.vector_stores.file_batches.upload_and_poll(
  vector_store_id=vector_store.id, files=file_streams
)
 
# You can print the status and the file counts of the batch to see the result of this operation.
print(file_batch.status)
print(file_batch.file_counts)
# Out:
# completed
# FileCounts(cancelled=0, completed=1, failed=0, in_progress=0, total=1)

# %%
assistant = client.beta.assistants.update(
  assistant_id=assistant.id,
  tool_resources={"file_search": {"vector_store_ids": [vector_store.id]}},
)

# %%
# Upload the user provided file to OpenAI
message_file = client.files.create(
  file=open("C:\\Users\\HP\\Desktop\\CATO CURSOS-1-2024\\GER-TI CATO1-2024\\Cursos\\SEMANA 17\\PREGUNTAS  AIKEN\\Charla virtual 10 estartegias de marketing.txt", "rb"), purpose="assistants"
)
 
# Create a thread and attach the file to the message
thread = client.beta.threads.create(
  messages=[
    {
      "role": "user",
      "content": """Elabora VEINTE preguntas en formato AIKEN del texto que te copio en adjunto.  
      Las preguntas deben ser principalmente del tema abordado en el texto.
      NUNCA das citaciones ni fuentes
      NUNCA das un texto de introduccion , ni de despedida 
      UNICAMENTE respondes con las preguntas solictadas haciendo como en el ejemplo, no mas y no menos
      El ejemplo de preguntas que debes generar son así:”
Según el texto de título: Business Storytelling Masterclass with Matteo Cassese, ¿qué es esencial para captar la atención del público en storytelling?
A) Utilizar terminología complicada
B) Hablar en un tono monótono
C) Empezar con una anécdota interesante
D) Presentar gráficos complejos
ANSWER: C
 """ ,
      # Attach the new file to the message.
      "attachments": [
        { "file_id": message_file.id, "tools": [{"type": "file_search"}] }
      ],
    }
  ]
)
 
# The thread now has a vector store with that file in its tool resources.
print(thread.tool_resources.file_search)
# Out:
# ToolResourcesFileSearch(vector_store_ids=['vs_Te9iQpxapsPx5ONeyinGozU1'])

# %%
# Use the create and poll SDK helper to create a run and poll the status of
# the run until it's in a terminal state.

run = client.beta.threads.runs.create_and_poll(
    thread_id=thread.id, assistant_id=assistant.id
)

messages = list(client.beta.threads.messages.list(thread_id=thread.id, run_id=run.id))

message_content = messages[0].content[0].text


print(message_content.value)
# Out:
# Según el video, ¿cuál es la primera estrategia de marketing digital para potenciar un emprendimiento?
# A) Publicidad en redes sociales
# B) Sitio web optimizado
# C) Email marketing
# D) Marketing de contenidos
# ANSWER: B
#
# ¿Por qué es importante tener un sitio web optimizado según el video?
# A) Porque es costoso de mantener
# B) Porque permite autonomía en la implementación de estrategias
# C) Porque reemplaza las redes sociales
# D) Porque no requiere actualización constante
# ANSWER: B
#
# ¿Qué se menciona como una ventaja de tener un sitio web propio?
# A) No necesita SEO
# B) Se pueden hacer cambios e implementar estrategias fácilmente
# C) No requiere inversión inicial
# D) No necesita contenido
# ANSWER: B
#
# ¿Cuál es la segunda estrategia de marketing digital mencionada en el video?
# A) Redes sociales
# B) Publicidad pagada
# C) Marketing de contenidos
# D) Marketing de afiliados
# ANSWER: C
#
# ¿Qué aspecto del sitio web es crucial para atraer tráfico según el video?
# A) Diseño gráfico complejo
# B) Optimización de tiempos de carga
# C) Uso de colores brillantes
# D) Inclusión de música de fondo
# ANSWER: B
#
# ¿Qué es SEO según el video?
# A) Una estrategia de redes sociales
# B) Optimización para motores de búsqueda
# C) Publicidad pagada en Google
# D) Email marketing automatizado
# ANSWER: B
#
# ¿Cuál es el principal objetivo del SEO?
# A) Aumentar la velocidad del sitio web
# B) Hacer que los contenidos sean encontrables en Google
# C) Eliminar contenido duplicado
# D) Crear campañas publicitarias
# ANSWER: B
#
# Según el video, ¿qué es fundamental para que un sitio web sea eficaz en marketing digital?
# A) Que sea únicamente informativo
# B) Que sea persuasivo
# C) Que use gráficos complejos
# D) Que no tenga contenido multimedia
# ANSWER: B
#
# ¿Qué se recomienda hacer con el contenido en un sitio web para mejorar su SEO?
# A) Publicar contenido una vez al año
# B) Actualizar y optimizar constantemente
# C) Evitar el uso de palabras clave
# D) Limitarse a un solo formato de contenido
# ANSWER: B
#
# ¿Cuál es la tercera estrategia de marketing digital mencionada en el video?
# A) Redes sociales
# B) SEO
# C) Publicidad pagada
# D) Marketing de afiliados
# ANSWER: B
#
# ¿Qué herramienta se menciona para registrar las páginas de un sitio web en Google?
# A) Google Analytics
# B) Google Ads
# C) Google Search Console
# D) Google Drive
# ANSWER: C
#
# ¿Cuál es el enfoque del marketing de contenidos según el video?
# A) Crear contenido para todos los canales digitales
# B) Publicar solo en redes sociales
# C) Evitar el uso de imágenes y videos
# D) Limitarse a contenido escrito
# ANSWER: A
#
# ¿Qué importancia tienen los sitios web en una estrategia de marketing digital según el video?
# A) Son secundarios a las redes sociales
# B) Son el centro de todas las estrategias
# C) No son necesarios si se usa publicidad pagada
# D) Solo son útiles para empresas grandes
# ANSWER: B
#
# ¿Qué estrategia se describe como soporte para todas las demás estrategias de marketing digital?
# A) SEO
# B) Marketing de contenidos
# C) Email marketing
# D) Publicidad pagada
# ANSWER: B
#
# ¿Por qué es crucial tener contenido optimizado en un sitio web?
# A) Para reducir costos de mantenimiento
# B) Para mejorar la experiencia del usuario y el SEO
# C) Para evitar el uso de publicidad pagada
# D) Para competir directamente con redes sociales
# ANSWER: B
#
# Según el video, ¿qué puede provocar que un sitio web no logre atraer prospectos?
# A) No tener gráficos complejos
# B) Ser meramente informativo y desactualizado
# C) No usar música de fondo
# D) Tener demasiado contenido multimedia
# ANSWER: B
#
# ¿Qué se recomienda hacer para mejorar la experiencia del usuario en un sitio web?
# A) Evitar el uso de formularios
# B) Optimizar tiempos de carga y contenido
# C) Limitar la interactividad
# D) Usar colores brillantes
# ANSWER: B
#
# ¿Cuál es el propósito principal del marketing de contenidos?
# A) Vender directamente productos
# B) Atraer y mantener la atención de la audiencia
# C) Sustituir el SEO
# D) Eliminar la necesidad de un sitio web
# ANSWER: B
#
# ¿Qué herramienta se menciona para hacer publicidad en Google?
# A) Google Search Console
# B) Google Analytics
# C) Google Ads
# D) Google Drive
# ANSWER: C
#
# ¿Cuál es la cuarta estrategia de marketing digital mencionada en el video?
# A) Publicidad online
# B) Email marketing
# C) Redes sociales
# D) Marketing de afiliados
# ANSWER: C
#
# Según el video, ¿por qué las redes sociales no deben ser la única estrategia de marketing digital?
# A) Porque son difíciles de usar
# B) Porque están enfocadas en beneficios monetarios para sus propietarios
# C) Porque no generan tráfico
# D) Porque no permiten la interacción con los usuarios
# ANSWER: B
#
# ¿Cuál es una de las principales ventajas de usar publicidad online según el video?
# A) No requiere inversión
# B) Permite segmentar y personalizar anuncios
# C) No necesita estrategias de contenido
# D) Es totalmente gratuita
# ANSWER: B
#
# ¿Qué se menciona como crucial para una estrategia efectiva de publicidad online?
# A) Evitar la segmentación de la audiencia
# B) Generar contenido de valor
# C) Publicar anuncios esporádicamente
# D) Usar solo un formato de anuncio
# ANSWER: B
#
# ¿Qué herramienta se menciona para hacer publicidad en Facebook e Instagram?
# A) Google Ads
# B) Meta Ads
# C) Google Analytics
# D) Google Search Console
# ANSWER: B
#
# ¿Qué es el remarketing según el video?
# A) Crear nuevos productos
# B) Segmentar la audiencia
# C) Mostrar anuncios a usuarios que no finalizaron una compra
# D) Publicar contenido informativo
# ANSWER: C
#
# ¿Cuál es la quinta estrategia de marketing digital mencionada en el video?
# A) Email marketing
# B) Marketing de contenidos
# C) Publicidad online
# D) Marketing de afiliados
# ANSWER: C
#
# ¿Por qué el email marketing vuelve a ser relevante según el video?
# A) Porque es más barato que otros métodos
# B) Porque permite una comunicación personalizada y segmentada
# C) Porque no requiere estrategia de contenidos
# D) Porque es fácil de automatizar
# ANSWER: B
#
# ¿Cuál es la sexta estrategia de marketing digital mencionada en el video?
# A) SEO
# B) Publicidad online
# C) Email marketing
# D) Redes sociales
# ANSWER: C
#
# ¿Qué herramienta se menciona para automatizar el email marketing?
# A) Google Ads
# B) Meta Ads
# C) MailChimp
# D) Google Search Console
# ANSWER: C
#
# ¿Qué es fundamental para el éxito del marketing automatizado según el video?
# A) Crear contenido una vez al año
# B) Tener una estrategia de contenidos integral
# C) Limitarse a una sola plataforma
# D) Evitar el uso de CRM
# ANSWER: B
